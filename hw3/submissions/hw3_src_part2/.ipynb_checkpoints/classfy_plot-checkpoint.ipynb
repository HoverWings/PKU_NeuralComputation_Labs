# %%
import matlab.engine
from scipy.io import loadmat
import pandas as pd
import numpy as np

# %%
spirals = loadmat('./data/spirals.mat')
print(spirals.keys())
spiral1 = pd.DataFrame(spirals["spiral_1"])
spiral1=spiral1.T
spiral2 = pd.DataFrame(spirals["spiral_2"])
spiral2=spiral2.T
# print(spiral1)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'spiral_1', 'spiral_2'])
#             0         1
# 0   -0.027874  0.265206
# 1   -0.116544  0.288457
# 2   -0.218902  0.280182
# 3   -0.323607  0.235114
# 4   -0.417641  0.152009
# 5   -0.487698  0.034103
# 6   -0.521679 -0.110886
# 7   -0.510147 -0.271250
# 8   -0.447589 -0.432232
# 9   -0.333333 -0.577350
# 10  -0.172033 -0.689988
# 11   0.026369 -0.755095
# 12   0.247214 -0.760845
# 13   0.472207 -0.700076
# 14   0.680928 -0.571367
# 15   0.852642 -0.379621
# 16   0.968262 -0.136080
# 17   1.012274  0.142266
# 18   0.974448  0.433852
# 19   0.851160  0.714208
# 20   0.646178  0.957999
# 21   0.370820  1.141268
# 22   0.043430  1.243686
# 23  -0.311810  1.250603
# 24  -0.666667  1.154701
# 25  -0.991090  0.957085
# 26  -1.255748  0.667693
# 27  -1.434616  0.304937
# 28  -1.507430 -0.105410
# 29  -1.461744 -0.532031
# ..        ...       ...
# 90  -0.139305 -0.727815
# 91   0.034027 -0.665377
# 92   0.256235 -0.838608
# 93   0.407925 -0.712817
# 94   0.666553 -0.636303
# 95   0.866192 -0.284631
# 96   0.949424 -0.151423
# 97   0.847160  0.084177
# 98   0.869953  0.404885
# 99   0.890579  0.828454
# 100  0.781066  0.949233
# 101  0.346806  1.202582
# 102  0.080192  1.301080
# 103 -0.253440  1.139580
# 104 -0.626139  1.147835
# 105 -1.048109  0.905065
# 106 -1.159638  0.606963
# 107 -1.527378  0.321039
# 108 -1.356622 -0.103493
# 109 -1.438622 -0.602400
# 110 -1.168861 -0.931082
# 111 -0.972663 -1.367245
# 112 -0.568616 -1.536725
# 113 -0.267883 -1.720857
# 114  0.274913 -1.742576
# 115  0.780018 -1.652045
# 116  1.171575 -1.411451
# 117  1.678204 -0.881884
# 118  1.792762 -0.360718
# 119  2.114456  0.012638
#
# [120 rows x 2 columns]

# %%
spiral1['label']=1
spiral2['label']=2
spirals=pd.concat([spiral1,spiral2],axis=0,ignore_index=True)
spirals
# Out:
#             0         1  label
# 0   -0.027874  0.265206      1
# 1   -0.116544  0.288457      1
# 2   -0.218902  0.280182      1
# 3   -0.323607  0.235114      1
# 4   -0.417641  0.152009      1
# 5   -0.487698  0.034103      1
# 6   -0.521679 -0.110886      1
# 7   -0.510147 -0.271250      1
# 8   -0.447589 -0.432232      1
# 9   -0.333333 -0.577350      1
# 10  -0.172033 -0.689988      1
# 11   0.026369 -0.755095      1
# 12   0.247214 -0.760845      1
# 13   0.472207 -0.700076      1
# 14   0.680928 -0.571367      1
# 15   0.852642 -0.379621      1
# 16   0.968262 -0.136080      1
# 17   1.012274  0.142266      1
# 18   0.974448  0.433852      1
# 19   0.851160  0.714208      1
# 20   0.646178  0.957999      1
# 21   0.370820  1.141268      1
# 22   0.043430  1.243686      1
# 23  -0.311810  1.250603      1
# 24  -0.666667  1.154701      1
# 25  -0.991090  0.957085      1
# 26  -1.255748  0.667693      1
# 27  -1.434616  0.304937      1
# 28  -1.507430 -0.105410      1
# 29  -1.461744 -0.532031      1
# ..        ...       ...    ...
# 210  0.129150  0.671236      2
# 211 -0.144067  0.719292      2
# 212 -0.347562  0.763118      2
# 213 -0.408226  0.730395      2
# 214 -0.733475  0.449076      2
# 215 -0.743141  0.533374      2
# 216 -0.959225  0.061838      2
# 217 -0.922441 -0.186715      2
# 218 -1.009684 -0.367374      2
# 219 -0.955052 -0.860965      2
# 220 -0.614627 -0.927944      2
# 221 -0.363685 -1.104016      2
# 222  0.037738 -1.170903      2
# 223  0.269168 -1.189855      2
# 224  0.679660 -1.192616      2
# 225  0.901592 -0.908562      2
# 226  1.229226 -0.664210      2
# 227  1.375145 -0.421226      2
# 228  1.520299  0.100749      2
# 229  1.551671  0.592159      2
# 230  1.373425  0.884291      2
# 231  0.942197  1.200658      2
# 232  0.670017  1.775092      2
# 233  0.235751  1.665858      2
# 234 -0.245960  1.666145      2
# 235 -0.905645  1.691611      2
# 236 -1.307387  1.410903      2
# 237 -1.515224  1.042819      2
# 238 -1.810076  0.418589      2
# 239 -1.950385  0.160388      2
#
# [240 rows x 3 columns]

# %%
x=spirals[[0,1]]
y=spirals['label']

# %%
from sklearn.model_selection import train_test_split
import keras
from keras import Sequential
from keras.layers import Dense

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=233)
x_train=x_train.values
x_test=x_test.values
y_train=y_train.values
y_test=y_test.values

# %%
model = Sequential()
model.add(Dense(100, input_dim=2, activation='relu'))
# model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# model.compile('adam', loss = 'mean_squared_error', metrics = ['accuracy'])
model.compile(loss='mean_squared_error', optimizer='sgd', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs=1000, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 100)               300
# _________________________________________________________________
# dense_36 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                1010
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 11,531
# Trainable params: 11,531
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(x_test,y_test)
# Out:
# 48/48 [==============================] - 0s 5ms/step
# [0.5422369639078776, 0.4583333333333333]
