# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.load('b80.npy')

# %%
plt.figure()
y=a
plt.plot()
# plt.plot(y)
plt.xlabel('NAS epochs')
plt.ylabel('loss & acc')
plt.plot(y[:,0],lw=2,label='acc')
plt.plot(y[:,1],lw=2,label='loss')
plt.legend(loc=0)
